# %% [markdown]
# # Hunyuan3D-2.1 Test on AeroPath Dataset
#
# This notebook tests the image-to-3D shape generation pipeline using slices from the AeroPath respiratory tract dataset.
#
# ## Setup
# Install hy3dgen from the Hunyuan3D-2 repo:
# ```bash
# cd models/Hunyuan3D-2
# pip install -e .
# ```

# %%
import sys
import os

# Add paths for hy3dgen
sys.path.insert(0, 'models/Hunyuan3D-2')

# %%
import numpy as np
import torch
import trimesh
import matplotlib.pyplot as plt
from IPython.display import Image as IPImage, display

from dataloaders import AeroPathDataset

# Import utilities from organized modules
from utils.preprocessing import prepare_slice_for_hunyuan, normalize_to_unit_range
from utils.visualization import (
    create_mesh_rotation_gif,
    create_comparison_gif,
    plot_slice_with_mask,
    points_to_mesh
)
from utils.metrics import evaluate_reconstruction, print_metrics
from utils.tools import load_mesh, mesh_to_pointcloud


# %matplotlib inline

# %%
# Uncomment to load the pipeline (requires GPU)
# from hy3dgen.shapegen import Hunyuan3DDiTFlowMatchingPipeline

# %% [markdown]
# ## Load AeroPath Dataset

# %%
# Load dataset with surface-only points (exterior boundary)
dataset = AeroPathDataset(
    root_dir="data",
    mask_type="lungs",
    plane="coronal",
    surface_only=True  # Extract only surface points for GT
)
print(f"Total samples: {len(dataset)}")
# Out:
# Total samples: 27

# %%
# Select a sample index
sample_idx = 8
slice_2d, mask_2d, point_cloud = dataset[sample_idx]

print(f"Slice shape: {slice_2d.shape}")
print(f"Mask shape: {mask_2d.shape}")
print(f"Point cloud shape: {point_cloud.shape} (surface points only)")
# Out:
# Slice shape: torch.Size([1, 487, 602])
# Mask shape: torch.Size([1, 487, 602])
# Point cloud shape: torch.Size([820077, 3]) (surface points only)

# %%
# Visualize the slice and mask using utility function
plot_slice_with_mask(slice_2d, mask_2d, rotate=True)
# Out:
# c:\Users\drago\OneDrive\Desktop\Robitcs Lab\Zero-Shot-SAM3Dfy\Zero-Shot-SAM3Dfy\utils\visualization.py:408: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## Prepare Image for Hunyuan3D

# %%
# Prepare the image using utility function
input_image = prepare_slice_for_hunyuan(
    slice_2d, mask_2d,
    use_mask_overlay=True,
    rotate=True
)

# Display
plt.figure(figsize=(8, 8))
plt.imshow(input_image)
plt.title('Input Image for Hunyuan3D')
plt.axis('off')
plt.show()

# Save for reference
os.makedirs('outputs', exist_ok=True)
input_image.save('outputs/aeropath_input.png')
# Out:
# C:\Users\drago\AppData\Local\Temp\ipykernel_71344\3946976934.py:13: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## Load Hunyuan3D Shape Generation Pipeline
#
# Using local weights from `models/Hunyuan3D-2.1`

# %%
# Uncomment to load and run the pipeline
# os.environ['HY3DGEN_MODELS'] = 'models'
#
# shape_pipeline = Hunyuan3DDiTFlowMatchingPipeline.from_pretrained(
#     'Hunyuan3D-2.1',
#     subfolder='hunyuan3d-dit-v2-1',
#     use_safetensors=False
# )
#
# # Generate mesh
# mesh = shape_pipeline(image=input_image, num_inference_steps=15)[0]
# mesh.export('outputs/aeropath_mesh.glb')

# %% [markdown]
# ## Load Existing Mesh and Evaluate

# %%
# Load existing mesh using utility function
output_mesh_path = 'outputs/aeropath_mesh.glb'
mesh = load_mesh(output_mesh_path)

print(f"Loaded mesh from: {output_mesh_path}")
print(f"Vertices: {len(mesh.vertices)}, Faces: {len(mesh.faces)}")
# Out:
# Loaded mesh from: outputs/aeropath_mesh.glb
# Vertices: 104372, Faces: 208752

# %%
# Extract and normalize point clouds
gt_points = point_cloud.numpy()
pred_points = mesh_to_pointcloud(mesh, n_points=200000)

print(f"Ground truth points: {gt_points.shape} (surface only)")
print(f"Predicted points: {pred_points.shape}")

# Normalize to [-1, 1] range using utility functions
gt_points_norm = normalize_to_unit_range(gt_points)
pred_points_norm = normalize_to_unit_range(pred_points)

print(f"\nAfter normalization:")
print(f"GT range: [{gt_points_norm.min():.3f}, {gt_points_norm.max():.3f}]")
print(f"Pred range: [{pred_points_norm.min():.3f}, {pred_points_norm.max():.3f}]")
# Out:
# Ground truth points: (820077, 3) (surface only)
# Predicted points: (200000, 3)
#
# After normalization:
# GT range: [-1.000, 1.000]
# Pred range: [-1.000, 1.000]

# %% [markdown]
# ## Compute Evaluation Metrics

# %%
# Compute all 7 evaluation metrics with ICP alignment
# metrics = evaluate_reconstruction(
#     pc_pred=pred_points_norm,
#     pc_gt=gt_points_norm,
#     threshold=0.01,
#     grid_size=64,
#     normalize=False,  # Already normalized
#     align=True  # Auto-align with ICP
# )

# # Print metrics using utility function
# print_metrics(metrics, title="Reconstruction Quality Metrics (with ICP alignment)")

# %% [markdown]
# ## Visualization

# %%
# Create comparison GIF (GT mesh vs Predicted mesh)
# GT point cloud is converted to mesh via convex hull
sample_name = "9_CT_HR"

comparison_gif_path = create_comparison_gif(
    gt_mesh_or_points=gt_points_norm,  # Will be converted to mesh
    pred_mesh_or_points=mesh,
    output_path='outputs/comparison.gif',
    sample_name=sample_name,
    n_frames=36,
    duration=0.1,
    use_icp_align=False,
    render_mesh=False,  # Render as point clouds with gray shading
    pred_rotation=('y', 90)  # Rotate predicted 90 degrees around x-axis to fix orientation
)

display(IPImage(filename=comparison_gif_path))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 5
#       1 # Create comparison GIF (GT mesh vs Predicted mesh)
#       2 # GT point cloud is converted to mesh via convex hull
#       3 sample_name = "9_CT_HR"
# ----> 5 comparison_gif_path = create_comparison_gif(
#       6     gt_mesh_or_points=gt_points_norm,  # Will be converted to mesh
#       7     pred_mesh_or_points=mesh,
#       8     output_path='outputs/comparison.gif',
#       9     sample_name=sample_name,
#      10     n_frames=36,
#      11     duration=0.1,
#      12     use_icp_align=False,
#      13     render_mesh=False,  # Render as point clouds with gray shading
#      14     pred_rotation=('y', 90)  # Rotate predicted 90 degrees around x-axis to fix orientation
#      15 )
#      17 display(IPImage(filename=comparison_gif_path))
#
# File c:\Users\drago\OneDrive\Desktop\Robitcs Lab\Zero-Shot-SAM3Dfy\Zero-Shot-SAM3Dfy\utils\visualization.py:355, in create_comparison_gif(gt_mesh_or_points, pred_mesh_or_points, output_path, sample_name, n_frames, duration, use_icp_align, render_mesh, gt_color, pred_color, pred_rotation)
#     351 ax_pred.set_box_aspect([1, 1, 1])
#     353 plt.tight_layout()
# --> 355 fig.canvas.draw()
#     356 buf = fig.canvas.buffer_rgba()
#     357 image = np.asarray(buf)[:, :, :3]
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:470, in Axes3D.draw(self, renderer)
#     467         axis.draw(renderer)
#     469 # Then rest
# --> 470 super().draw(renderer)
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\axes\_base.py:3226, in _AxesBase.draw(self, renderer)
#    3223 if artists_rasterized:
#    3224     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3226 mimage._draw_list_compositing_images(
#    3227     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3229 renderer.close_group('axes')
#    3230 self.stale = False
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\artist.py:38, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      35     renderer.stop_rasterizing()
#      36     renderer._rasterizing = False
# ---> 38 return draw(artist, renderer, *args, **kwargs)
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\mpl_toolkits\mplot3d\art3d.py:770, in Path3DCollection.draw(self, renderer)
#     768 with self._use_zordered_offset():
#     769     with cbook._setattr_cm(self, _in_draw=True):
# --> 770         super().draw(renderer)
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\collections.py:1008, in _CollectionWithSizes.draw(self, renderer)
#    1005 @artist.allow_rasterization
#    1006 def draw(self, renderer):
#    1007     self.set_sizes(self._sizes, self.get_figure(root=True).dpi)
# -> 1008     super().draw(renderer)
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\collections.py:430, in Collection.draw(self, renderer)
#     421         ipaths, ilinestyles = self._get_inverse_paths_linestyles()
#     422         renderer.draw_path_collection(
#     423             gc, transform.frozen(), ipaths,
#     424             self.get_transforms(), offsets, offset_trf,
#    (...)
#     427             self._antialiaseds, self._urls,
#     428             "screen")
# --> 430     renderer.draw_path_collection(
#     431         gc, transform.frozen(), paths,
#     432         self.get_transforms(), offsets, offset_trf,
#     433         self.get_facecolor(), self.get_edgecolor(),
#     434         self._linewidths, self._linestyles,
#     435         self._antialiaseds, self._urls,
#     436         "screen")  # offset_position, kept for backcompat.
#     438 gc.restore()
#     439 renderer.close_group(self.__class__.__name__)
#
# File c:\Users\drago\anaconda3\envs\hy3d\lib\site-packages\matplotlib\path.py:223, in Path.codes(self)
#     220     self._vertices = vertices
#     221     self._update_values()
# --> 223 @property
#     224 def codes(self):
#     225     """
#     226     The list of codes in the `Path` as a 1D array.
#     227
#    (...)
#     231     of `vertices` and `codes` is always the same.
#     232     """
#     233     return self._codes
#
# KeyboardInterrupt:
